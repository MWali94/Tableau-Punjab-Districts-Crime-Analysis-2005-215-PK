# %%
import pandas as pd

# %%
raw_csv_data = pd.read_csv("/Users/wali/Downloads/punjab-crime-statistics.csv") #importing data
df = raw_csv_data.copy()

# %%
df.head(100)
# Out:
#     Year Province         Division      District                 Crime Type  \
# 0   2002   Punjab       Bahawalpur    Bahawalpur               All Reported
# 1   2002   Punjab       Bahawalpur    Bahawalpur                     Murder
# 2   2002   Punjab       Bahawalpur    Bahawalpur           Attempted Murder
# 3   2002   Punjab       Bahawalpur    Bahawalpur                       Hurt
# 4   2002   Punjab       Bahawalpur    Bahawalpur                    Rioting
# 5   2002   Punjab       Bahawalpur    Bahawalpur  Assault on Govt. Servants
# 6   2002   Punjab       Bahawalpur    Bahawalpur                       Rape
# 7   2002   Punjab       Bahawalpur    Bahawalpur      Kidnapping/ Abduction
# 8   2002   Punjab       Bahawalpur    Bahawalpur                    Dacoity
# 9   2002   Punjab       Bahawalpur    Bahawalpur                    Robbery
# 10  2002   Punjab       Bahawalpur    Bahawalpur                   Burglary
# ...

# %%
pd.options.display.max_columns = None #setting to view full dataset
pd.options.display.max_rows = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6885 entries, 0 to 6884
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               6885 non-null   int64
#  1   Province           6885 non-null   object
#  2   Division           6885 non-null   object
#  3   District           6885 non-null   object
#  4   Crime Type         6885 non-null   object
#  5   Crime No           6885 non-null   int64
#  6   Population         6885 non-null   float64
#  7   Normalised/100000  6885 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 430.4+ KB

# %%
df.describe()
# Out:
#               Year      Crime No    Population  Normalised/100000
# count  6885.000000   6885.000000  6.885000e+03        6885.000000
# mean   2008.995643   1332.465214  2.613794e+06         183.277905
# std       3.861148   4542.091264  1.601153e+06       11436.330254
# min    2002.000000      0.000000  1.770383e+01           0.000000
# 25%    2006.000000     54.000000  1.424000e+06           2.635432
# 50%    2009.000000    163.000000  2.346000e+06           7.418761
# 75%    2012.000000    527.000000  3.212000e+06          19.382716
# max    2015.000000  86707.000000  9.744000e+06      948947.368400

# %%
df = df.drop(['Normalised/100000'], axis=1)

# %%
df = df.drop(['Province'], axis=1) #droping 'province' column because it has constant value

# %%
df.head(50)
# Out:
#     Year         Division      District                 Crime Type  Crime No  \
# 0   2002       Bahawalpur    Bahawalpur               All Reported      8440
# 1   2002       Bahawalpur    Bahawalpur                     Murder       105
# 2   2002       Bahawalpur    Bahawalpur           Attempted Murder       226
# 3   2002       Bahawalpur    Bahawalpur                       Hurt       700
# 4   2002       Bahawalpur    Bahawalpur                    Rioting        12
# 5   2002       Bahawalpur    Bahawalpur  Assault on Govt. Servants        39
# 6   2002       Bahawalpur    Bahawalpur                       Rape        63
# 7   2002       Bahawalpur    Bahawalpur      Kidnapping/ Abduction       243
# 8   2002       Bahawalpur    Bahawalpur                    Dacoity        24
# 9   2002       Bahawalpur    Bahawalpur                    Robbery       195
# 10  2002       Bahawalpur    Bahawalpur                   Burglary       998
# ...

# %%
df_processing = df[['District', 'Crime Type','Crime No']].head(31)

# %%
df_processing
# Out:
#         District                 Crime Type  Crime No
# 0     Bahawalpur               All Reported      8440
# 1     Bahawalpur                     Murder       105
# 2     Bahawalpur           Attempted Murder       226
# 3     Bahawalpur                       Hurt       700
# 4     Bahawalpur                    Rioting        12
# 5     Bahawalpur  Assault on Govt. Servants        39
# 6     Bahawalpur                       Rape        63
# 7     Bahawalpur      Kidnapping/ Abduction       243
# 8     Bahawalpur                    Dacoity        24
# 9     Bahawalpur                    Robbery       195
# 10    Bahawalpur                   Burglary       998
# 11    Bahawalpur       Motor Vehicles Theft       175
# 12    Bahawalpur               Cattle Theft       150
# 13    Bahawalpur            Ordinary Thefts        61
# 14    Bahawalpur                      Misc.      5449
# 15  Bahawalnagar               All Reported      6728
# ...

# %%
df_processing.head(16)
# Out:
#         District                 Crime Type  Crime No
# 0     Bahawalpur               All Reported      8440
# 1     Bahawalpur                     Murder       105
# 2     Bahawalpur           Attempted Murder       226
# 3     Bahawalpur                       Hurt       700
# 4     Bahawalpur                    Rioting        12
# 5     Bahawalpur  Assault on Govt. Servants        39
# 6     Bahawalpur                       Rape        63
# 7     Bahawalpur      Kidnapping/ Abduction       243
# 8     Bahawalpur                    Dacoity        24
# 9     Bahawalpur                    Robbery       195
# 10    Bahawalpur                   Burglary       998
# 11    Bahawalpur       Motor Vehicles Theft       175
# 12    Bahawalpur               Cattle Theft       150
# 13    Bahawalpur            Ordinary Thefts        61
# 14    Bahawalpur                      Misc.      5449
# 15  Bahawalnagar               All Reported      6728

# %%
df_District_Bahawalpur = df_processing.head(15)
df_District_Bahawalpur
# Out:
#       District                 Crime Type  Crime No
# 0   Bahawalpur               All Reported      8440
# 1   Bahawalpur                     Murder       105
# 2   Bahawalpur           Attempted Murder       226
# 3   Bahawalpur                       Hurt       700
# 4   Bahawalpur                    Rioting        12
# 5   Bahawalpur  Assault on Govt. Servants        39
# 6   Bahawalpur                       Rape        63
# 7   Bahawalpur      Kidnapping/ Abduction       243
# 8   Bahawalpur                    Dacoity        24
# 9   Bahawalpur                    Robbery       195
# 10  Bahawalpur                   Burglary       998
# 11  Bahawalpur       Motor Vehicles Theft       175
# 12  Bahawalpur               Cattle Theft       150
# 13  Bahawalpur            Ordinary Thefts        61
# 14  Bahawalpur                      Misc.      5449

# %%
column_sum = df_District_Bahawalpur['Crime No'].sum()  # Column[Crime type] has a cell 'All reported' which is showing the total number of Crime in one district,Which needs to be removed 
print(column_sum)                                      #column_sum - 'All Reported' giving the total number of crime reported in a district
# Out:
# 16880

# %%
new_df_District_Bahawalpur = df_District_Bahawalpur.loc[df_District_Bahawalpur['Crime Type']== 'All Reported']

# %%
new_df_District_Bahawalpur
# Out:
#      District    Crime Type  Crime No
# 0  Bahawalpur  All Reported      8440

# %%
new_total_CT_df = df.loc[df['Crime Type'] == 'All Reported'] #checking 'all reported' value, if we need that value or not
new_total_CT_df
# Out:
#       Year         Division           District    Crime Type  Crime No  \
# 0     2002       Bahawalpur         Bahawalpur  All Reported      8440
# 15    2002       Bahawalpur       Bahawalnagar  All Reported      6728
# 30    2002       Bahawalpur           R.Y.Khan  All Reported      9032
# 45    2002  Dera Ghazi Khan           D.G.Khan  All Reported      3573
# 60    2002  Dera Ghazi Khan             Layyah  All Reported      2030
# 75    2002  Dera Ghazi Khan       Muzaffargarh  All Reported     10186
# 90    2002  Dera Ghazi Khan           Rajanpur  All Reported      3750
# 105   2002       Faisalabad         Faisalabad  All Reported     20306
# 120   2002       Faisalabad              Jhang  All Reported      7145
# 135   2002       Faisalabad          T.T.Singh  All Reported      3678
# 150   2002       Gujranwala         Gujranwala  All Reported     11037
# 165   2002       Gujranwala             Gujrat  All Reported      9480
# ...

# %%
new_total_CT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 459 entries, 0 to 6870
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        459 non-null    int64
#  1   Division    459 non-null    object
#  2   District    459 non-null    object
#  3   Crime Type  459 non-null    object
#  4   Crime No    459 non-null    int64
#  5   Population  459 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 25.1+ KB

# %%
without_allReported_Df = df.loc[df['Crime Type'] != 'All Reported']  #removing 'all reported' value from the dataset
without_allReported_Df
# Out:
#       Year         Division           District                 Crime Type  \
# 1     2002       Bahawalpur         Bahawalpur                     Murder
# 2     2002       Bahawalpur         Bahawalpur           Attempted Murder
# 3     2002       Bahawalpur         Bahawalpur                       Hurt
# 4     2002       Bahawalpur         Bahawalpur                    Rioting
# 5     2002       Bahawalpur         Bahawalpur  Assault on Govt. Servants
# 6     2002       Bahawalpur         Bahawalpur                       Rape
# 7     2002       Bahawalpur         Bahawalpur      Kidnapping/ Abduction
# 8     2002       Bahawalpur         Bahawalpur                    Dacoity
# 9     2002       Bahawalpur         Bahawalpur                    Robbery
# 10    2002       Bahawalpur         Bahawalpur                   Burglary
# 11    2002       Bahawalpur         Bahawalpur       Motor Vehicles Theft
# 12    2002       Bahawalpur         Bahawalpur               Cattle Theft
# ...

# %%
df['Population'] = df['Population'].astype(int)  #changing the datatype

# %%
without_allReported_Df.head(60)     #printing just head of the dataset
# Out:
#     Year         Division      District                 Crime Type  Crime No  \
# 1   2002       Bahawalpur    Bahawalpur                     Murder       105
# 2   2002       Bahawalpur    Bahawalpur           Attempted Murder       226
# 3   2002       Bahawalpur    Bahawalpur                       Hurt       700
# 4   2002       Bahawalpur    Bahawalpur                    Rioting        12
# 5   2002       Bahawalpur    Bahawalpur  Assault on Govt. Servants        39
# 6   2002       Bahawalpur    Bahawalpur                       Rape        63
# 7   2002       Bahawalpur    Bahawalpur      Kidnapping/ Abduction       243
# 8   2002       Bahawalpur    Bahawalpur                    Dacoity        24
# 9   2002       Bahawalpur    Bahawalpur                    Robbery       195
# 10  2002       Bahawalpur    Bahawalpur                   Burglary       998
# 11  2002       Bahawalpur    Bahawalpur       Motor Vehicles Theft       175
# ...

# %%
Total_crimeNo = without_allReported_Df['Crime No'].sum()   #finding total crime number by taking sum of Crime-No column
Total_crimeNo
# Out:
# 4586460

# %%
without_allReported_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6426 entries, 1 to 6884
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        6426 non-null   int64
#  1   Division    6426 non-null   object
#  2   District    6426 non-null   object
#  3   Crime Type  6426 non-null   object
#  4   Crime No    6426 non-null   int64
#  5   Population  6426 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 351.4+ KB

# %%
without_allReported_Df.to_csv('/Users/wali/Downloads/preprocess-punjab-crime-statistics.csv', index=False)

# %%
without_allReported_Df.to_excel('/Users/wali/Downloads/preprocess-punjab-crime-statistics.xlsx', index=False) #saving processed dataset in excel format to computer for visual representation using Tableau dashboards.

# %%
Bahawalpur_Df = without_allReported_Df.loc[without_allReported_Df['Division'] == 'Bahawalpur'] #extracting single division from dataset for analysis
Bahawalpur_Df
# Out:
#       Year    Division      District                 Crime Type  Crime No  \
# 1     2002  Bahawalpur    Bahawalpur                     Murder       105
# 2     2002  Bahawalpur    Bahawalpur           Attempted Murder       226
# 3     2002  Bahawalpur    Bahawalpur                       Hurt       700
# 4     2002  Bahawalpur    Bahawalpur                    Rioting        12
# 5     2002  Bahawalpur    Bahawalpur  Assault on Govt. Servants        39
# 6     2002  Bahawalpur    Bahawalpur                       Rape        63
# 7     2002  Bahawalpur    Bahawalpur      Kidnapping/ Abduction       243
# 8     2002  Bahawalpur    Bahawalpur                    Dacoity        24
# 9     2002  Bahawalpur    Bahawalpur                    Robbery       195
# 10    2002  Bahawalpur    Bahawalpur                   Burglary       998
# 11    2002  Bahawalpur    Bahawalpur       Motor Vehicles Theft       175
# 12    2002  Bahawalpur    Bahawalpur               Cattle Theft       150
# ...

# %%
Bahawalpur_Df.to_excel('/Users/wali/Downloads/preBahawalpur-punjab-crime-statistics.xlsx', index=False)

# %%
Lahore_Df = without_allReported_Df.loc[without_allReported_Df['Division'] == 'Lahore']
Lahore_Df
# Out:
#       Year Division       District                 Crime Type  Crime No  \
# 241   2002   Lahore         Lahore                     Murder       506
# 242   2002   Lahore         Lahore           Attempted Murder       689
# 243   2002   Lahore         Lahore                       Hurt      1262
# 244   2002   Lahore         Lahore                    Rioting         0
# 245   2002   Lahore         Lahore  Assault on Govt. Servants        46
# 246   2002   Lahore         Lahore                       Rape        48
# 247   2002   Lahore         Lahore      Kidnapping/ Abduction       608
# 248   2002   Lahore         Lahore                    Dacoity        70
# 249   2002   Lahore         Lahore                    Robbery      1384
# 250   2002   Lahore         Lahore                   Burglary      1262
# 251   2002   Lahore         Lahore       Motor Vehicles Theft      2048
# 252   2002   Lahore         Lahore               Cattle Theft       108
# ...

# %%
Lahore_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 770 entries, 241 to 6659
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        770 non-null    int64
#  1   Division    770 non-null    object
#  2   District    770 non-null    object
#  3   Crime Type  770 non-null    object
#  4   Crime No    770 non-null    int64
#  5   Population  770 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 42.1+ KB

# %%
Lahore_Df.to_excel('/Users/wali/Downloads/preLahore-punjab-crime-statistics.xlsx', index=False)
